# %% [markdown]
# ### Prep the data for modeling.
#
# * Take ratio to make new features
# * Start with a select number of features
# * Create dummy or indicator features for categorical variables
# * Standardize the magnitude of numeric features using a scaler
# * Split your data into testing and training datasets

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import import_ipynb
import Data_Cleanup as dc

cwd = os.getcwd()
maindir = os.path.dirname(cwd)
print(maindir)
# Out:
# importing Jupyter notebook from Data_Cleanup.ipynb
# /Users/maureenkeenan/Desktop/Kaggle/WiDs_Datathon_2020

# %%
filepath = os.path.join(maindir,'data')
df = pd.read_csv(os.path.join(filepath,'InterimData.csv'))

#Check out the data
df.head()
# Out:
#    encounter_id  patient_id  hospital_id  hospital_death   age    bmi  \
# 0         66154       25312          118               0  68.0  22.73
# 1        114252       59342           81               0  77.0  27.42
# 2        119783       50777          118               0  25.0  31.95
# 3         79267       46918          118               0  81.0  22.64
# 4         92056       34377           33               0  19.0    NaN
#
#    elective_surgery  ethnicity gender  height  ...  Survived has_h1  has_d1  \
# 0                 0  Caucasian      M   180.3  ...  Survived      1       1
# 1                 0  Caucasian      F   160.0  ...  Survived      1       1
# 2                 0  Caucasian      F   172.7  ...  Survived      1       1
# 3                 1  Caucasian      F   165.1  ...  Survived      1       1
# 4                 0  Caucasian      M   188.0  ...  Survived      1       1
#
#   has_both has_inv  has_lmin  lactate_min  creatinine  albumin  ACR
# 0        2       1         1          1.0         2.3      2.3  1.0
# 1        2       1         1          3.5         1.6      1.6  1.0
# 2        2       1         1          1.0         NaN      3.0  NaN
# 3        2       1         1          1.0         NaN      3.0  NaN
# 4        2       1         1          1.0         NaN      3.0  NaN
#
# [5 rows x 196 columns]

# %%
#Check the table to see if it has the NaN corrections
df.isnull().sum()
# Out:
# encounter_id          0
# patient_id            0
# hospital_id           0
# hospital_death        0
# age                4228
#                   ...
# has_lmin              0
# lactate_min           0
# creatinine        48228
# albumin               0
# ACR               48228
# Length: 196, dtype: int64

# %%
# Transform the data
df = dc.transform_data(df)

# %%
features = ['hospital_id','age','bmi',
            'ethnicity','elective_surgery','has_h1','icu_admit_source', 'icu_type',
            'apache_3j_bodysystem','apache_3j_diagnosis','apache_2_diagnosis',
            'lactate_min','ACR','h1_temp_min']

# %%
# Split into X (select features) and y
y = df.hospital_death

X = df[features]

# %%
X.head()
#fillNA and encode and scale
# Out:
#    hospital_id   age        bmi  ethnicity  elective_surgery  has_h1  \
# 0          118  68.0  22.730000  Caucasian                 0       1
# 1           81  77.0  27.420000  Caucasian                 0       1
# 2          118  25.0  31.950000  Caucasian                 0       1
# 3          118  81.0  22.640000  Caucasian                 1       1
# 4           33  19.0  27.654655  Caucasian                 0       1
#
#             icu_admit_source      icu_type apache_3j_bodysystem  \
# 0                      Floor         CTICU               Sepsis
# 1                      Floor  Med-Surg ICU          Respiratory
# 2       Accident & Emergency  Med-Surg ICU            Metabolic
# 3  Operating Room / Recovery         CTICU       Cardiovascular
# 4       Accident & Emergency  Med-Surg ICU               Trauma
#
#    apache_3j_diagnosis  apache_2_diagnosis  lactate_min  ACR  h1_temp_min
# 0               502.01               113.0          1.0  1.0         37.5
# 1               203.01               108.0          3.5  1.0         36.3
# 2               703.03               122.0          1.0  NaN         36.7
# 3              1206.03               203.0          1.0  NaN         34.8
# 4               601.01               119.0          1.0  NaN          NaN

# %%
X.isnull().sum()
# Out:
# hospital_id                 0
# age                         0
# bmi                         0
# ethnicity                   0
# elective_surgery            0
# has_h1                      0
# icu_admit_source          112
# icu_type                    0
# apache_3j_bodysystem     1662
# apache_3j_diagnosis      1101
# apache_2_diagnosis       1662
# lactate_min                 0
# ACR                     48228
# h1_temp_min             21732
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(X,y,test_size = 0.2, stratify=y)

# %%
# Create function to process Xtrain 
def pipeline(Xdata):
    # Fix NA
    Xdata['ACR'] = Xdata['ACR'].fillna(0)
    Xdata['h1_temp_min'] = Xdata['h1_temp_min'].fillna(np.mean(Xdata['h1_temp_min']))
    Xdata = Xdata.dropna(axis=0)
    
    # Encode categorical
    Xdata = pd.get_dummies(Xdata)
    
    # Scaled numerical
    from sklearn.preprocessing import StandardScaler
    trained_scaler = StandardScaler().fit(Xdata)
    
    return Xdata, trained_scaler

# %%
# Process Xtrain
Xtrain, scaler = pipeline(Xtrain)
Xtrain_transformed = scaler.transform(Xtrain)

# Process Xtest
Xtest, unused = pipeline(Xtest)
Xtest_transformed = scaler.transform(Xtest)
